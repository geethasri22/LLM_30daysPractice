# %%
# !pip install -q transformers

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
text = "Artificial Intelligence is transforming the world."

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['Art', 'ificial', 'ĠIntelligence', 'Ġis', 'Ġtransforming', 'Ġthe', 'Ġworld', '.']

# %%
token_ids = tokenizer.encode(text)

print(token_ids)
# Out:
# [8001, 9542, 9345, 318, 25449, 262, 995, 13]

# %%
decoded = tokenizer.decode(token_ids)

print(decoded)
# Out:
# Artificial Intelligence is transforming the world.

# %%
print("Number of Tokens:", len(token_ids))
# Out:
# Number of Tokens: 8

# %%
sentences = [
    "Hello!",
    "Artificial Intelligence",
    "I love learning Large Language Models.",
    "ChatGPT is an AI assistant."
]

for sentence in sentences:
    ids = tokenizer.encode(sentence)
    print("=" * 50)
    print("Sentence:", sentence)
    print("Tokens:", tokenizer.tokenize(sentence))
    print("Token Count:", len(ids))
# Out:
# ==================================================
# Sentence: Hello!
# Tokens: ['Hello', '!']
# Token Count: 2
# ==================================================
# Sentence: Artificial Intelligence
# Tokens: ['Art', 'ificial', 'ĠIntelligence']
# Token Count: 3
# ==================================================
# Sentence: I love learning Large Language Models.
# Tokens: ['I', 'Ġlove', 'Ġlearning', 'ĠLarge', 'ĠLanguage', 'ĠModels', '.']
# Token Count: 7
# ==================================================
# Sentence: ChatGPT is an AI assistant.
# Tokens: ['Chat', 'G', 'PT', 'Ġis', 'Ġan', 'ĠAI', 'Ġassistant', '.']
# Token Count: 8
